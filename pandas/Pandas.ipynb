# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\S\Downloads\movies_metadata.csv",encoding='latin1',on_bad_lines='skip')

# %%
data.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5  False                                                NaN  60000000
# 6  False                                                NaN  58000000
# 7  False                                                NaN         0
# 8  False                                                NaN  35000000
# 9  False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
data.dtypes
# Out:
# adult                       bool
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# id                         int64
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                    int64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                       bool
# vote_average             float64
# vote_count                 int64
# dtype: object

# %%
type(data.adult)
# Out:
# pandas.core.series.Series

# %%
type(data[["adult","homepage"]])
# Out:
# pandas.core.frame.DataFrame

# %%
data[:5]
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
data.loc[:5,["homepage","budget","genres","id"]]
# Out:
#                                homepage    budget  \
# 0  http://toystory.disney.com/toy-story  30000000
# 1                                   NaN  65000000
# 2                                   NaN         0
# 3                                   NaN  16000000
# 4                                   NaN         0
# 5                                   NaN  60000000
#
#                                               genres     id
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    949

# %%
data.iloc[:7,1:6]
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5                                                NaN  60000000
# 6                                                NaN  58000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
# ...

# %%
db=data[data["original_title"]=="Toy Story"]

# %%
db
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#    release_date    revenue runtime                          spoken_languages  \
# 0    1995-10-30  373554033    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7       5415
#
# [1 rows x 24 columns]

# %%
high_budget_movie=data.loc[data.budget>=30000000]

# %%
high_budget_movie
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 13  False                                                NaN  44000000
# 14  False                                                NaN  98000000
# 15  False                                                NaN  52000000
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 19  False                                                NaN  60000000
# ...

# %%
d2=data.dropna()
d2.shape
# Out:
# (1, 24)

# %%
have_collection=data.loc[data["belongs_to_collection"].isna()==False]
have_collection
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 20  False  {'id': 91698, 'name': 'Chili Palmer Collection...  30250000
# 32  False  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
# 42  False  {'id': 9818, 'name': 'Mortal Kombat Collection...  18000000
# 46  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# ...

# %%
popular_high_rating=data[(data.id>=15602) & (data["vote_average"]>=7.1)]
popular_high_rating
# Out:
#     adult                              belongs_to_collection  budget  \
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...       0
# 27  False                                                NaN       0
#
#                                                genres homepage     id  \
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      NaN  21032
# 27  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  17015
#
#       imdb_id original_language original_title  \
# 12  tt0112453                en          Balto
# 27  tt0114117                en     Persuasion
#
#                                              overview  ...  release_date  \
# 12  An outcast half-wolf risks his life to prevent...  ...    1995-12-22
# 27  This film adaptation of Jane Austen's last nov...  ...    1995-09-27
#
#      revenue runtime                          spoken_languages    status  \
# 12  11348324    78.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
data.describe()
# Out:
#              budget             id  popularity       revenue     runtime  \
# count  4.900000e+01      49.000000   49.000000  4.900000e+01   49.000000
# mean   2.154796e+07   15842.816327    8.932256  7.705440e+07  110.081633
# std    2.433495e+07   23561.689658    4.967530  1.091120e+08   25.476163
# min    0.000000e+00       5.000000    0.114469  0.000000e+00   50.000000
# 25%    0.000000e+00    1408.000000    5.231580  0.000000e+00   99.000000
# 50%    1.200000e+07    9603.000000    9.481338  2.334157e+07  106.000000
# 75%    3.300000e+07   15602.000000   11.712900  1.161124e+08  122.000000
# max    9.800000e+07  139405.000000   21.946943  3.735540e+08  192.000000
#
#        vote_average   vote_count
# count     49.000000    49.000000
# mean       6.551020   704.326531
# std        0.824905  1262.325242
# min        3.500000     2.000000
# 25%        6.100000    72.000000
# 50%        6.500000   199.000000
# 75%        7.100000   539.000000
# max        8.100000  5915.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  49 non-null     bool
#  1   belongs_to_collection  10 non-null     object
#  2   budget                 49 non-null     int64
#  3   genres                 49 non-null     object
#  4   homepage               5 non-null      object
#  5   id                     49 non-null     int64
#  6   imdb_id                49 non-null     object
#  7   original_language      49 non-null     object
#  8   original_title         49 non-null     object
#  9   overview               48 non-null     object
#  10  popularity             49 non-null     float64
#  11  poster_path            49 non-null     object
#  12  production_companies   49 non-null     object
#  13  production_countries   49 non-null     object
# ...

# %%
d=data.dropna(axis=1,how="any")
d.shape
# Out:
# (49, 20)

# %%
d1=data.dropna(axis=0,how="any")
d1.shape
# Out:
# (1, 24)

# %%
data.dropna(axis=0, thresh=23)
#keeping only rows with atleast 23 not - Na values
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 12  False  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 18  False  {'id': 3167, 'name': 'Ace Ventura Collection',...  30000000
# 20  False  {'id': 91698, 'name': 'Chili Palmer Collection...  30250000
# 24  False                                                NaN   3600000
# 32  False  {'id': 9435, 'name': 'Babe Collection', 'poste...  30000000
# 42  False  {'id': 9818, 'name': 'Mortal Kombat Collection...  18000000
# 45  False                                                NaN  33000000
# 46  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# ...

# %%
data.drop(["overview","tagline"],axis=1)
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
data.homepage.fillna("harshi")
# Out:
# 0                  http://toystory.disney.com/toy-story
# 1                                                harshi
# 2                                                harshi
# 3                                                harshi
# 4                                                harshi
# 5                                                harshi
# 6                                                harshi
# 7                                                harshi
# 8                                                harshi
# 9          http://www.mgm.com/view/movie/757/Goldeneye/
# 10                                               harshi
# 11                                               harshi
# 12                                               harshi
# 13                                               harshi
# 14                                               harshi
# 15                                               harshi
# 16                                               harshi
# ...

# %%
data.rename(columns={"original_language":"og_lang","belongs_to_collection":"have_c"})
# Out:
#     adult                                             have_c    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   False                                                NaN  16000000
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 7   False                                                NaN         0
# 8   False                                                NaN  35000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  False                                                NaN  62000000
# 11  False                                                NaN         0
# ...

# %%
data.budget.sort_values(ascending=False)
# Out:
# 14    98000000
# 1     65000000
# 10    62000000
# 5     60000000
# 19    60000000
# 6     58000000
# 9     58000000
# 46    55000000
# 15    52000000
# 22    50000000
# 13    44000000
# 8     35000000
# 45    33000000
# 20    30250000
# 18    30000000
# 32    30000000
# 0     30000000
# 30    29500000
# 43    20000000
# 41    19000000
# 42    18000000
# 28    18000000
# 16    16500000
# 3     16000000
# 37    12000000
# 26    12000000
# 34    11000000
# 40    10000000
# 44    10000000
# 48     6000000
# 17     4000000
# 24     3600000
# 21           0
# 47           0
# 2            0
# 4            0
# 7            0
# 11           0
# 12           0
# 29           0
# 31           0
# 38           0
# 23           0
# 36           0
# 35           0
# 25           0
# 33           0
# 27           0
# 39           0
# Name: budget, dtype: int64

# %%
data.sort_values(by=["budget","id"],ascending=False)
# Out:
#     adult                              belongs_to_collection    budget  \
# 14  False                                                NaN  98000000
# 1   False                                                NaN  65000000
# 10  False                                                NaN  62000000
# 19  False                                                NaN  60000000
# 5   False                                                NaN  60000000
# 6   False                                                NaN  58000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 46  False  {'id': 136214, 'name': 'Pocahontas Collection'...  55000000
# 15  False                                                NaN  52000000
# 22  False                                                NaN  50000000
# 13  False                                                NaN  44000000
# 8   False                                                NaN  35000000
# ...

# %%
data.overview.str

# %%
data.tagline=data.tagline.str.lower().head()

# %%
data.tagline
# Out:
# 0                                                   NaN
# 1             roll the dice and unleash the excitement!
# 2     still yelling. still fighting. still ready for...
# 3     friends are the people who let you be yourself...
# 4     just when his world is back to normal... he's ...
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
data["original_language"]=data["original_language"].str.replace("en","Harshi")

# %%
data["original_language"]
# Out:
# 0     Harshi
# 1     Harshi
# 2     Harshi
# 3     Harshi
# 4     Harshi
# 5     Harshi
# 6     Harshi
# 7     Harshi
# 8     Harshi
# 9     Harshi
# 10    Harshi
# 11    Harshi
# 12    Harshi
# 13    Harshi
# 14    Harshi
# 15    Harshi
# 16    Harshi
# 17    Harshi
# 18    Harshi
# 19    Harshi
# 20    Harshi
# 21    Harshi
# 22    Harshi
# 23    Harshi
# 24    Harshi
# 25    Harshi
# 26    Harshi
# 27    Harshi
# 28        fr
# 29    Harshi
# 30    Harshi
# 31        fr
# 32    Harshi
# 33    Harshi
# 34    Harshi
# 35    Harshi
# 36    Harshi
# 37    Harshi
# 38    Harshi
# 39    Harshi
# 40    Harshi
# 41    Harshi
# 42    Harshi
# 43    Harshi
# 44    Harshi
# 45    Harshi
# 46    Harshi
# 47    Harshi
# 48    Harshi
# Name: original_language, dtype: object

# %%
data.budget=data.budget.astype("float32")
data.budget
# Out:
# 0     30000000.0
# 1     65000000.0
# 2            0.0
# 3     16000000.0
# 4            0.0
# 5     60000000.0
# 6     58000000.0
# 7            0.0
# 8     35000000.0
# 9     58000000.0
# 10    62000000.0
# 11           0.0
# 12           0.0
# 13    44000000.0
# 14    98000000.0
# 15    52000000.0
# 16    16500000.0
# 17     4000000.0
# 18    30000000.0
# 19    60000000.0
# 20    30250000.0
# 21           0.0
# 22    50000000.0
# 23           0.0
# 24     3600000.0
# 25           0.0
# 26    12000000.0
# 27           0.0
# 28    18000000.0
# 29           0.0
# 30    29500000.0
# 31           0.0
# 32    30000000.0
# 33           0.0
# 34    11000000.0
# 35           0.0
# 36           0.0
# 37    12000000.0
# 38           0.0
# 39           0.0
# 40    10000000.0
# 41    19000000.0
# 42    18000000.0
# 43    20000000.0
# 44    10000000.0
# 45    33000000.0
# 46    55000000.0
# 47           0.0
# 48     6000000.0
# Name: budget, dtype: float32

# %%
data=data.astype({"budget":"float64","runtime":"int32"},copy=False) 
#copy is used in astype instead of inplace

# %%
data
# Out:
#     adult                              belongs_to_collection      budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1   False                                                NaN  65000000.0
# 2   False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3   False                                                NaN  16000000.0
# 4   False  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
# 5   False                                                NaN  60000000.0
# 6   False                                                NaN  58000000.0
# 7   False                                                NaN         0.0
# 8   False                                                NaN  35000000.0
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000.0
# 10  False                                                NaN  62000000.0
# 11  False                                                NaN         0.0
# ...

# %%
import pandas as pd
df = pd.DataFrame(
    {
        "area": [1200, 1522, 1458, 2578, 5685, 5845, 5987, 4548],
        "mumbai_price": [11, 22, 12, 45, 77, 85, 47, 95],
        "pune_price": [14, 15, 36, 42, 56, 56, 36, 35],
        "raigad_price": [78, 56, 56, 56, 58, 32, 56, 33],
    }
)
df
# Out:
#    area  mumbai_price  pune_price  raigad_price
# 0  1200            11          14            78
# 1  1522            22          15            56
# 2  1458            12          36            56
# 3  2578            45          42            56
# 4  5685            77          56            58
# 5  5845            85          56            32
# 6  5987            47          36            56
# 7  4548            95          35            33

# %%
pd.melt(df)
# Out:
#         variable  value
# 0           area   1200
# 1           area   1522
# 2           area   1458
# 3           area   2578
# 4           area   5685
# 5           area   5845
# 6           area   5987
# 7           area   4548
# 8   mumbai_price     11
# 9   mumbai_price     22
# 10  mumbai_price     12
# 11  mumbai_price     45
# 12  mumbai_price     77
# 13  mumbai_price     85
# 14  mumbai_price     47
# 15  mumbai_price     95
# 16    pune_price     14
# 17    pune_price     15
# 18    pune_price     36
# 19    pune_price     42
# 20    pune_price     56
# 21    pune_price     56
# 22    pune_price     36
# 23    pune_price     35
# 24  raigad_price     78
# 25  raigad_price     56
# 26  raigad_price     56
# 27  raigad_price     56
# 28  raigad_price     58
# 29  raigad_price     32
# 30  raigad_price     56
# 31  raigad_price     33

# %%
df.columns
# Out:
# Index(['area', 'mumbai_price', 'pune_price', 'raigad_price'], dtype='object')

# %%
pd.melt(df,id_vars="area",value_vars=["mumbai_price","pune_price","raigad_price"])
# Out:
#     area      variable  value
# 0   1200  mumbai_price     11
# 1   1522  mumbai_price     22
# 2   1458  mumbai_price     12
# 3   2578  mumbai_price     45
# 4   5685  mumbai_price     77
# 5   5845  mumbai_price     85
# 6   5987  mumbai_price     47
# 7   4548  mumbai_price     95
# 8   1200    pune_price     14
# 9   1522    pune_price     15
# 10  1458    pune_price     36
# 11  2578    pune_price     42
# 12  5685    pune_price     56
# 13  5845    pune_price     56
# 14  5987    pune_price     36
# 15  4548    pune_price     35
# 16  1200  raigad_price     78
# 17  1522  raigad_price     56
# 18  1458  raigad_price     56
# 19  2578  raigad_price     56
# 20  5685  raigad_price     58
# 21  5845  raigad_price     32
# 22  5987  raigad_price     56
# 23  4548  raigad_price     33

# %%
df=pd.melt(df,id_vars="area",value_vars=["mumbai_price","pune_price","raigad_price"],var_name="Area",value_name="Rs in lakhs")
df
# Out:
#     area          Area  Rs in lakhs
# 0   1200  mumbai_price           11
# 1   1522  mumbai_price           22
# 2   1458  mumbai_price           12
# 3   2578  mumbai_price           45
# 4   5685  mumbai_price           77
# 5   5845  mumbai_price           85
# 6   5987  mumbai_price           47
# 7   4548  mumbai_price           95
# 8   1200    pune_price           14
# 9   1522    pune_price           15
# 10  1458    pune_price           36
# 11  2578    pune_price           42
# 12  5685    pune_price           56
# 13  5845    pune_price           56
# 14  5987    pune_price           36
# 15  4548    pune_price           35
# 16  1200  raigad_price           78
# 17  1522  raigad_price           56
# 18  1458  raigad_price           56
# 19  2578  raigad_price           56
# 20  5685  raigad_price           58
# 21  5845  raigad_price           32
# 22  5987  raigad_price           56
# 23  4548  raigad_price           33

# %%
pd.pivot(df,columns="Area",index="area",values=["Rs in lakhs"])
# Out:
#       Rs in lakhs
# Area mumbai_price pune_price raigad_price
# area
# 1200           11         14           78
# 1458           12         36           56
# 1522           22         15           56
# 2578           45         42           56
# 4548           95         35           33
# 5685           77         56           58
# 5845           85         56           32
# 5987           47         36           56

# %%
df1 = pd.DataFrame(
    {
        "area": [1200, 1522, 1458, 2578, 5685, 5845, 5987, 4548],
        "mumbai_price": [11, 22, 12, 45, 77, 85, 47, 95],
        "pune_price": [14, 15, 36, 42, 56, 56, 36, 35],
        "raigad_price": [78, 56, 56, 56, 58, 32, 56, 33],
    }
)
df1
# Out:
#    area  mumbai_price  pune_price  raigad_price
# 0  1200            11          14            78
# 1  1522            22          15            56
# 2  1458            12          36            56
# 3  2578            45          42            56
# 4  5685            77          56            58
# 5  5845            85          56            32
# 6  5987            47          36            56
# 7  4548            95          35            33

# %%
df1.mumbai_price.unique()
# Out:
# array([11, 22, 12, 45, 77, 85, 47, 95], dtype=int64)

# %%
df1.mumbai_price.nunique()
# Out:
# 8

# %%
df1.area.value_counts()
# Out:
# area
# 1200    1
# 1522    1
# 1458    1
# 2578    1
# 5685    1
# 5845    1
# 5987    1
# 4548    1
# Name: count, dtype: int64

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "foo", "foo", "foo", "foo", "bar", "bar", "bar", "bar"],
        "B": ["one", "one", "one", "two", "two", "one", "one", "two", "two"],
        "C": [
            "small",
            "large",
            "large",
            "small",
            "small",
            "large",
            "small",
            "small",
            "large",
        ],
        "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
        "E": [2, 4, 5, 5, 6, 6, 8, 9, 9],
    }
)
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
import numpy as np
pd.pivot_table(df,columns='B',index=["A","C"],values="E",aggfunc=np.sum)
# Out:
# C:\Users\S\AppData\Local\Temp\ipykernel_11364\3375929986.py:2: FutureWarning: The provided callable <function sum at 0x0000020E2CDD8FE0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,columns='B',index=["A","C"],values="E",aggfunc=np.sum)
# B          one   two
# A   C
# bar large  6.0   9.0
#     small  8.0   9.0
# foo large  9.0   NaN
#     small  2.0  11.0

# %%
import pandas as pd

df = pd.DataFrame(
    {
        "Name": ["kathy", "linda", "peter", "john", "fatima", "kaval", "dhabir", "dev"],
        "Nationality": [
            "usa",
            "usa",
            "bangladesh",
            "india",
            "india",
            "bangladesh",
            "usa",
            "india",
        ],
        "Sex": ["female", "female", "male", "male", "female", "female", "male", "male"],
        "Age": [15, 18, 14, 17, 15, 16, 19, 25],
        "Handedness": [
            "right",
            "left",
            "right",
            "left",
            "left",
            "right",
            "left",
            "right",
        ],
    }
)

df
# Out:
#      Name Nationality     Sex  Age Handedness
# 0   kathy         usa  female   15      right
# 1   linda         usa  female   18       left
# 2   peter  bangladesh    male   14      right
# 3    john       india    male   17       left
# 4  fatima       india  female   15       left
# 5   kaval  bangladesh  female   16      right
# 6  dhabir         usa    male   19       left
# 7     dev       india    male   25      right

# %%
df.groupby("Sex")

# %%
df.groupby("Nationality").max()
# Out:
#               Name   Sex  Age Handedness
# Nationality
# bangladesh   peter  male   16      right
# india         john  male   25      right
# usa          linda  male   19      right

# %%
df.groupby("Nationality").min()
# Out:
#                Name     Sex  Age Handedness
# Nationality
# bangladesh    kaval  female   14      right
# india           dev  female   15       left
# usa          dhabir  female   15       left

# %%
df.groupby("Age").max()
# Out:
#        Name Nationality     Sex Handedness
# Age
# 14    peter  bangladesh    male      right
# 15    kathy         usa  female      right
# 16    kaval  bangladesh  female      right
# 17     john       india    male       left
# 18    linda         usa  female       left
# 19   dhabir         usa    male       left
# 25      dev       india    male      right

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   left  right
# Nationality
# bangladesh      0      2
# india           2      1
# usa             2      1

# %%
pd.crosstab(df.Sex,df.Handedness)
# Out:
# Handedness  left  right
# Sex
# female         2      2
# male           2      2

# %%
pd.crosstab(df.Sex,[df.Handedness,df.Nationality],margins=True)
# Out:
# Handedness   left          right           All
# Nationality india usa bangladesh india usa
# Sex
# female          1   1          1     0   1   4
# male            1   1          1     1   0   4
# All             2   2          2     1   1   8

# %%
pd.crosstab([df.Handedness,df.Nationality],df.Sex,margins=True)
# Out:
# Sex                     female  male  All
# Handedness Nationality
# left       india             1     1    2
#            usa               1     1    2
# right      bangladesh        1     1    2
#            india             0     1    1
#            usa               1     0    1
# All                          4     4    8

# %%
pd.crosstab(df.Sex, df.Handedness, normalize="index")
# Out:
# Handedness  left  right
# Sex
# female       0.5    0.5
# male         0.5    0.5

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)

df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "E": ["D8", "D9", "D10", "D11"],
        "F": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

df3
# Out:
#       A    B    C    E    F
# 8    A8   B8   C8   D8   D8
# 9    A9   B9   C9   D9   D9
# 10  A10  B10  C10  D10  D10
# 11  A11  B11  C11  D11  D11

# %%
#by default axis=0 make sure columns are same otherwisw eill give NaN
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D    E    F
# 0    A0   B0   C0   D0  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN
# 4    A4   B4   C4   D4  NaN  NaN
# 5    A5   B5   C5   D5  NaN  NaN
# 6    A6   B6   C6   D6  NaN  NaN
# 7    A7   B7   C7   D7  NaN  NaN
# 8    A8   B8   C8  NaN   D8   D8
# 9    A9   B9   C9  NaN   D9   D9
# 10  A10  B10  C10  NaN  D10  D10
# 11  A11  B11  C11  NaN  D11  D11

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

# Creating second dataframe
df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[0, 1, 2, 3],
)

# Creating third dataframe
df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[0, 1, 2, 4],
)
#make sure index are same
pd.concat([df1,df2,df3],axis=1)
# Out:
#      A    B    C    D    A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0   A4   B4   C4   D4   A8   B8   C8   D8
# 1   A1   B1   C1   D1   A5   B5   C5   D5   A9   B9   C9   D9
# 2   A2   B2   C2   D2   A6   B6   C6   D6  A10  B10  C10  D10
# 3   A3   B3   C3   D3   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
d1 = pd.DataFrame(
    {
        "Key": ["K0", "K1", "K2", "K3"],
        "A": ["A0", "A4", "A2", "A3"],
        "B": ["B0", "B4", "B2", "B3"],
    }
)

d2 = pd.DataFrame(
    {
        "Key": ["K0", "K1", "K2", "K5"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

d1
# Out:
#   Key   A   B
# 0  K0  A0  B0
# 1  K1  A4  B4
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
d2
# Out:
#   Key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K5  C3  D3

# %%
pd.merge(d1,d2,how="right",on="Key")
# Out:
#   Key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1   A4   B4  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K5  NaN  NaN  C3  D3

# %%
pd.get_dummies(d1)
# Out:
#    Key_K0  Key_K1  Key_K2  Key_K3   A_A0   A_A2   A_A3   A_A4   B_B0   B_B2  \
# 0    True   False   False   False   True  False  False  False   True  False
# 1   False    True   False   False  False  False  False   True  False  False
# 2   False   False    True   False  False   True  False  False  False   True
# 3   False   False   False    True  False  False   True  False  False  False
#
#     B_B3   B_B4
# 0  False  False
# 1  False   True
# 2  False  False
# 3   True  False

# %%
# d2["Key"]=d2.Key.map({"K0":0,"K1":1,"K2":2,"K5":3})
# d2

# %%
print(d2.Key)
print(d2.Key.values)
# Out:
# 0    K0
# 1    K1
# 2    K2
# 3    K5
# Name: Key, dtype: object
# ['K0' 'K1' 'K2' 'K5']

# %%
def LabelEncode(a):
    for i in range (len(d2.Key.unique())):
        d2["Key"][i]=i
    return d2

# %%
LabelEncode(d2.Key)
# Out:
#   Key   C   D
# 0   0  C0  D0
# 1   1  C1  D1
# 2   2  C2  D2
# 3   3  C3  D3
