# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x_data=np.random.randn(100)
x_data
# Out:
# array([ 0.73207673,  0.47815101,  1.08403192,  1.20997684, -0.04598173,
#        -0.42680723,  0.40756652, -0.13054679, -0.93922884, -0.78452642,
#         0.04218232,  0.80606   ,  0.01923284, -0.7328873 , -0.66895395,
#        -0.62386821,  0.55544049, -1.61669866,  0.76436525,  1.36229187,
#         0.27225087,  0.46774382, -0.4401102 , -1.55040422,  1.29645565,
#         0.91106378,  0.26964868, -2.91324683,  1.05322535,  2.15740398,
#        -0.02411536, -0.08649924,  0.4467665 , -0.10224844,  1.56354048,
#        -1.40450373,  1.45518538, -1.33041046,  1.51122123,  0.64237581,
#         0.63621135, -1.74006649,  1.22158173, -0.06268759,  0.31537297,
#        -0.68061919, -0.85054225, -0.09140307, -1.15859771,  0.47111144,
#        -1.84332738, -1.61752259,  1.7067728 , -1.68327585,  1.20277852,
#        -0.61964891, -1.89240761, -1.27535009, -0.88589066, -0.78758815,
#        -0.36011926, -0.49038814, -1.37916274, -0.10142328,  1.51988621,
# ...

# %%
data=np.linspace(1.4,5,100)
sns.scatterplot(x=data,y=data**3)
# Out:
# <Axes: >

# %%
x_data=np.random.randn(100,2)
x_data
# Out:
# array([[ 0.53386949,  1.16193796],
#        [-0.47612298,  0.48731788],
#        [-3.40339833, -0.93251482],
#        [-0.78511241,  1.374456  ],
#        [-0.68226344, -0.21340494],
#        [-0.91196273, -0.64250643],
#        [-0.137349  ,  1.68095619],
#        [ 0.18940902,  0.14895659],
#        [ 0.60271378,  0.9015007 ],
#        [-0.97090157,  1.14060959],
#        [-0.93563034,  0.80974397],
#        [ 0.60725043,  0.34707861],
#        [ 1.4332707 ,  1.43849485],
#        [-1.29605524,  0.29687161],
#        [ 0.8787431 ,  1.09796416],
#        [ 0.66393402,  1.3916128 ],
#        [ 1.43649679,  1.09565414],
#        [ 2.41968268,  1.2740321 ],
#        [ 0.36036523,  1.26592172],
#        [-1.37467233,  0.04753057],
#        [-0.06527113,  0.24881128],
#        [-0.94160391, -0.30941807],
#        [-2.30961841,  0.16333043],
#        [ 0.60394505,  0.53670549],
#        [-1.90924515,  1.4123218 ],
#        [ 0.74230157, -0.68519653],
#        [-0.72047874,  1.36056396],
# ...

# %%
sns.scatterplot(x=x_data[:,0],y=x_data[:,1])
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_feature=PolynomialFeatures(degree=3,include_bias=False)

# %%
x_data_temp=poly_feature.fit_transform(x_data)
x_data_temp[:5]
# a b
#here a and b are two dimensions

# a,b,ab,a2,b2,a3,b3,a2b,b2a
# Out:
# array([[ 5.33869491e-01,  1.16193796e+00,  2.85016634e-01,
#          6.20323228e-01,  1.35009982e+00,  1.52161685e-01,
#          3.31171646e-01,  7.20777106e-01,  1.56873224e+00],
#        [-4.76122979e-01,  4.87317882e-01,  2.26693091e-01,
#         -2.32023242e-01,  2.37478718e-01, -1.07933790e-01,
#          1.10471597e-01, -1.13069075e-01,  1.15727626e-01],
#        [-3.40339833e+00, -9.32514822e-01,  1.15831202e+01,
#          3.17371939e+00,  8.69583894e-01, -3.94219721e+01,
#         -1.08014313e+01, -2.95954038e+00, -8.10899870e-01],
#        [-7.85112413e-01,  1.37445600e+00,  6.16401501e-01,
#         -1.07910247e+00,  1.88912929e+00, -4.83944470e-01,
#          8.47216741e-01, -1.48317886e+00,  2.59652509e+00],
#        [-6.82263440e-01, -2.13404942e-01,  4.65483402e-01,
#          1.45598390e-01,  4.55416694e-02, -3.17582307e-01,
#         -9.93364585e-02, -3.10714160e-02, -9.71881732e-03]])

# %%
x_data=np.random.randn(10000,1)

# %%
y_data = 5.7 + 3.6 * x_data + 2.4 * (x_data ** 2) + np.random.randn(10000, 1)

# %%
x_data.shape
# Out:
# (10000, 1)

# %%
y_data.shape
# Out:
# (10000, 1)

# %%
plt.scatter(x=x_data,y=y_data)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,random_state=47,test_size=0.2)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((8000, 1), (8000, 1), (2000, 1), (2000, 1))

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.4868715531387384

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4868715531387384

# %%
lr.score(x_train,y_train)
# Out:
# 0.5097626837693467

# %%
lr.coef_,lr.intercept_
# Out:
# (array([[3.60271937]]), array([8.13600814]))

# %%
plt.scatter(x_data,y_data)
plt.plot(x_test,y_pred,color="red")

# %% [markdown]
# # Polynomial regression
# We apply polynomial regression as data set is non linear and not linearly predictable

# %%
poly_feat=PolynomialFeatures(degree=2,include_bias=False)

# %%
x_data_high_dim=poly_feat.fit_transform(x_data)
x_data_high_dim[:2]
# Out:
# array([[-0.87807822,  0.77102135],
#        [-2.22384762,  4.94549824]])

# %%
plt.scatter(x_data_high_dim[:,0],y_data)

# %%
plt.scatter(x_data_high_dim[:,1],y_data)

# %%
plt.scatter(x_data_high_dim[:,0],x_data_high_dim[:,1])

# %%
x_pol_train,x_pol_test,y_pol_train,y_pol_test=train_test_split(x_data_high_dim,y_data,test_size=0.2,random_state=47)

# %%
x_pol_train.shape,y_pol_train.shape,x_pol_test.shape,y_pol_test.shape
# Out:
# ((8000, 2), (8000, 1), (2000, 2), (2000, 1))

# %%
poly_reg=lr.fit(x_pol_train,y_pol_train)

# %%
poly_reg.score(x_pol_train,y_pol_train)
# Out:
# 0.9614548540259379

# %%
y_pred_high_dim=lr.predict(x_pol_test)

# %%
r2_score(y_pol_test,y_pred_high_dim)
# Out:
# 0.9619692176926063

# %%
poly_reg.score(x_pol_test,y_pol_test)
# Out:
# 0.9619692176926063

# %%
plt.scatter(x_data,y_data)
plt.plot([[-3], [-2], [-1], [0], [1], [2], [3]],lr.predict(poly_feat.transform([[-3], [-2], [-1], [0], [1], [2], [3]])),color="black")
plt.plot(x_test,y_pred,c="red")
# plt.plot([[-3], [-2], [-1], [0], [1], [2], [3]],poly_feat.transform([[-3], [-2], [-1], [0], [1], [2], [3]]),color="green")

# %%
lr.coef_
# Out:
# array([[3.59410856, 2.39891644]])

# %%
lr.intercept_
# Out:
# array([5.70203607])
